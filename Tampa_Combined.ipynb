# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/sample_data/Tampa_Cleaned2.csv')

# %%
print(df.columns)
# Out:
# Index(['Hospital Name', 'Description', 'CPT Code', 'Code Type', 'payer_name',
#        'plan_name', 'Negotiated Price', 'In/Out Patient'],
#       dtype='object')

# %%
print(df['Hospital Name'].unique())
# Out:
# ['Fishermens Health' nan 'Mariners Hospital' 'Homestead Hospital']

# %%
df = df[df['Code Type'] == 'CPT']

# %%
print(df['Hospital Name'].unique())
# Out:
# ['Fishermens Health' 'Mariners Hospital' 'Homestead Hospital']

# %%
df
# Out:
#               Hospital Name                          Description CPT Code  \
# 16        Fishermens Health           BMT-Chimerism & CD56 cells    81268
# 19        Fishermens Health          BMT-HLA Class I antibody HD    86832
# 20        Fishermens Health      BMT-Post transplant engraftment    81267
# 21        Fishermens Health           BMT-pre transplant profile    81265
# 22        Fishermens Health        Amikacin Peak|Amikacin Trough    80150
# ...                     ...                                  ...      ...
# 1048512  Homestead Hospital               Ligation of iliac vein    37660
# 1048533  Homestead Hospital        Temporal artery procedure bil    37609
# 1048536  Homestead Hospital        Temporal artery procedure uni    37609
# 1048550  Homestead Hospital  Shiga toxin 1 (c)|Shiga toxin 2 (c)    87899
# 1048553  Homestead Hospital  Shiga toxin 1 (c)|Shiga toxin 2 (c)    87899
#
#         Code Type             payer_name                     plan_name  \
# ...

# %%
df = df.drop(columns=["Code Type"])

# %%
df
# Out:
#               Hospital Name                          Description CPT Code  \
# 16        Fishermens Health           BMT-Chimerism & CD56 cells    81268
# 19        Fishermens Health          BMT-HLA Class I antibody HD    86832
# 20        Fishermens Health      BMT-Post transplant engraftment    81267
# 21        Fishermens Health           BMT-pre transplant profile    81265
# 22        Fishermens Health        Amikacin Peak|Amikacin Trough    80150
# ...                     ...                                  ...      ...
# 1048512  Homestead Hospital               Ligation of iliac vein    37660
# 1048533  Homestead Hospital        Temporal artery procedure bil    37609
# 1048536  Homestead Hospital        Temporal artery procedure uni    37609
# 1048550  Homestead Hospital  Shiga toxin 1 (c)|Shiga toxin 2 (c)    87899
# 1048553  Homestead Hospital  Shiga toxin 1 (c)|Shiga toxin 2 (c)    87899
#
#                     payer_name                     plan_name  \
# ...

# %%
print(df['Hospital Name'].unique())
# Out:
# ['Fishermens Health' 'Mariners Hospital' 'Homestead Hospital']

# %%
df = df.rename(columns={
    # Adjust as necessary for your actual column names:
    "Hospital Name": "hospital_name",
    "Description": "description",
    "In/Out Patient": "setting",
    "Negotiated Price": "standard_charge|negotiated_dollar",
    "CPT Code": "cpt_code"
})

# %%
print(df['hospital_name'].unique())
# Out:
# ['Fishermens Health' 'Mariners Hospital' 'Homestead Hospital']

# %%
df
# Out:
#             hospital_name                                  description  \
# 16      Fishermens Health                   BMT-Chimerism & CD56 cells
# 19      Fishermens Health                  BMT-HLA Class I antibody HD
# 20      Fishermens Health              BMT-Post transplant engraftment
# 21      Fishermens Health                   BMT-pre transplant profile
# 22      Fishermens Health                Amikacin Peak|Amikacin Trough
# ...                   ...                                          ...
# 679696  Mariners Hospital                  Rpr s/n/ax/gen/trnk 2.5cm/<
# 679703  Mariners Hospital  Aldosterone 24 hour urine|Aldosterone-blood
# 679704  Mariners Hospital                 Glomerular basement membr Ab
# 679707  Mariners Hospital                          S cerevisiae IgA(c)
# 679710  Mariners Hospital                      Brain & stem MRI wo con
#
#        cpt_code         payer_name                     plan_name  \
# ...

# %%
desired_order = [
    'hospital_name',
    'description',
    'setting',
    'payer_name',
    'plan_name',
    'standard_charge|negotiated_dollar',
    'cpt_code'
]

df = df[desired_order]
df
# Out:
#               hospital_name                          description     setting  \
# 16        Fishermens Health           BMT-Chimerism & CD56 cells  Outpatient
# 19        Fishermens Health          BMT-HLA Class I antibody HD  Outpatient
# 20        Fishermens Health      BMT-Post transplant engraftment  Outpatient
# 21        Fishermens Health           BMT-pre transplant profile  Outpatient
# 22        Fishermens Health        Amikacin Peak|Amikacin Trough  Outpatient
# ...                     ...                                  ...         ...
# 1048512  Homestead Hospital               Ligation of iliac vein   Inpatient
# 1048533  Homestead Hospital        Temporal artery procedure bil   Inpatient
# 1048536  Homestead Hospital        Temporal artery procedure uni   Inpatient
# 1048550  Homestead Hospital  Shiga toxin 1 (c)|Shiga toxin 2 (c)  Outpatient
# 1048553  Homestead Hospital  Shiga toxin 1 (c)|Shiga toxin 2 (c)  Outpatient
#
# ...

# %%
print(df['hospital_name'].unique())
# Out:
# ['Fishermens Health' 'Mariners Hospital' 'Homestead Hospital']

# %%
null_counts = df.isnull().sum()
print("Count of null values per column:")
print(null_counts)
# Out:
# Count of null values per column:
# hospital_name                        0
# description                          0
# setting                              0
# payer_name                           0
# plan_name                            0
# standard_charge|negotiated_dollar    0
# cpt_code                             0
# dtype: int64

# %%
duplicate_count = df.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 98851

# %%
df = df.drop_duplicates()

# %%
print(df['hospital_name'].unique())
# Out:
# ['Fishermens Health' 'Mariners Hospital' 'Homestead Hospital']

# %%
df
# Out:
#               hospital_name                      description     setting  \
# 16        Fishermens Health       BMT-Chimerism & CD56 cells  Outpatient
# 19        Fishermens Health      BMT-HLA Class I antibody HD  Outpatient
# 20        Fishermens Health  BMT-Post transplant engraftment  Outpatient
# 21        Fishermens Health       BMT-pre transplant profile  Outpatient
# 22        Fishermens Health    Amikacin Peak|Amikacin Trough  Outpatient
# ...                     ...                              ...         ...
# 1048508  Homestead Hospital       Ligation of iliac vein bil   Inpatient
# 1048509  Homestead Hospital       Limited or localized fu CT  Outpatient
# 1048512  Homestead Hospital           Ligation of iliac vein   Inpatient
# 1048533  Homestead Hospital    Temporal artery procedure bil   Inpatient
# 1048536  Homestead Hospital    Temporal artery procedure uni   Inpatient
#
#                     payer_name                     plan_name  \
# ...

# %%
duplicate_count = df.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
df.to_csv('updated_tampa_cleaned2.csv', index=0)

# %%
df1 = pd.read_csv("/content/updated_tampa_cleaned2.csv")
df2 = pd.read_csv("/content/sample_data/updated_part_of_Tampa_data (1).csv")

# Combine them by stacking rows
df_merged = pd.concat([df1, df2], ignore_index=True)

# Save the merged DataFrame to a new CSV
df_merged.to_csv("combined_file.csv", index=False)

# %%
null_counts = df_merged.isnull().sum()
print("Count of null values per column:")
print(null_counts)
# Out:
# Count of null values per column:
# hospital_name                        0
# description                          0
# setting                              0
# payer_name                           0
# plan_name                            0
# standard_charge|negotiated_dollar    0
# cpt_code                             0
# dtype: int64

# %%
duplicate_count = df_merged.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

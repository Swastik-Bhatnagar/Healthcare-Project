# %%
import pandas as pd

# %%
df1 = pd.read_excel('/content/590910342_Baptist-Hospital-of-Miami-Inc_standardcharges.xlsx')

# %%
df1.head()
# Out:
#      hospital_name                                        description  \
# 0  Bapist hospital  Scw cann ft 7.0x80mm msdf7080|Scw cann ft 7.0x...
# 1  Bapist hospital  Scw cann hdless th p26572110f|Scw hless th p26...
# 2  Bapist hospital                     Scw cann DartFir Edge d0330026
# 3  Bapist hospital  Scw cann headless 3x20 3173020|Scw hdlss cann ...
# 4  Bapist hospital  Graft AAA Zenith 26x124 proxi|Graft AAA Zenith...
#
#                                               code|1 code|1|type  code|2  \
# 0  211374|211375|191574|191575|191576|191577|1915...         CDM   278.0
# 1                                      209407|209396         CDM   278.0
# 2                                             216377         CDM   278.0
# 3  190663|180152|178302|189906|217544|216987|2169...         CDM   278.0
# 4   150390|150383|158003|158020|158005|158007|158011         CDM   278.0
#
#   code|2|type code|3 code|3|type  code|4  code|4|type  ...  \
# ...

# %%
df1.isnull().sum()
# Out:
# hospital_name                                  0
# description                                    0
# code|1                                     79717
# code|1|type                                79717
# code|2                                     32151
# code|2|type                                32151
# code|3                                    108274
# code|3|type                               108274
# code|4                                   1048573
# code|4|type                              1048573
# modifiers                                 580915
# setting                                        0
# drug_unit_of_measurement                  931512
# drug_type_of_measurement                  931512
# standard_charge|gross                          0
# standard_charge|discounted_cash                0
# payer_name                                     0
# plan_name                                      0
# standard_charge|negotiated_dollar              0
# ...

# %%
df1['code|3|type'].value_counts()
# Out:
# code|3|type
# CPT    390839
# Name: count, dtype: int64

# %%
df1 = df1[df1['code|3|type'] == 'CPT'].reset_index()
df1 = df1.drop('index', axis=1)

# %%
df1 = df1.fillna(0)

# %%
df1.isnull().sum()
# Out:
# hospital_name                            0
# description                              0
# code|1                                   0
# code|1|type                              0
# code|2                                   0
# code|2|type                              0
# code|3                                   0
# code|3|type                              0
# code|4                                   0
# code|4|type                              0
# modifiers                                0
# setting                                  0
# drug_unit_of_measurement                 0
# drug_type_of_measurement                 0
# standard_charge|gross                    0
# standard_charge|discounted_cash          0
# payer_name                               0
# plan_name                                0
# standard_charge|negotiated_dollar        0
# standard_charge|negotiated_percentage    0
# standard_charge|negotiated_algorithm     0
# estimated_amount                         0
# ...

# %%
cols_to_rmv = ['modifiers', 'drug_unit_of_measurement', 'drug_type_of_measurement', 'standard_charge|gross', 'standard_charge|discounted_cash', 'standard_charge|negotiated_percentage', 'standard_charge|negotiated_algorithm', 'estimated_amount', 'standard_charge|methodology', 'standard_charge|min', 'standard_charge|max']

# %%
df1 = df1.drop(cols_to_rmv, axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390839 entries, 0 to 390838
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   hospital_name                      390839 non-null  object
#  1   description                        390839 non-null  object
#  2   code|1                             390839 non-null  object
#  3   code|1|type                        390839 non-null  object
#  4   code|2                             390839 non-null  float64
#  5   code|2|type                        390839 non-null  object
#  6   code|3                             390839 non-null  object
#  7   code|3|type                        390839 non-null  object
#  8   code|4                             390839 non-null  float64
#  9   code|4|type                        390839 non-null  float64
#  10  setting                            390839 non-null  object
# ...

# %%
df2 = pd.read_excel('/content/592616017_university-of-miami-hosp--clinics_standardcharges.xlsx')

# %%
df2.isnull().sum()
# Out:
# hospitak_name                                  0
# description                                    0
# code|1                                         0
# code|1|type                                    0
# code|2                                     13937
# code|2|type                                13937
# code|3                                    540713
# code|3|type                               540713
# billing_class                                  0
# setting                                        0
# drug_unit_of_measurement                  774667
# drug_type_of_measurement                  774667
# standard_charge|gross                      55249
# standard_charge|discounted_cash            55270
# payer_name                                     0
# plan_name                                      0
# modifiers                                1048573
# standard_charge|negotiated_dollar          87564
# standard_charge|negotiated_percentage     961057
# ...

# %%
df2['code|3|type'].value_counts()
# Out:
# code|3|type
# HCPCS    221077
# CPT      196162
# NDC       90621
# Name: count, dtype: int64

# %%
df2 = df2[df2['code|3|type']=='CPT']
df2 = df2.reset_index(drop=True)

# %%
df2.rename(columns={'hospitak_name': 'hospital_name'}, inplace=True)

# %%
df2 = df2.fillna(0)
df2.isnull().sum()
# Out:
# hospital_name                        0
# description                          0
# code|1                               0
# code|1|type                          0
# code|2                               0
# code|2|type                          0
# code|3                               0
# code|3|type                          0
# billing_class                        0
# setting                              0
# payer_name                           0
# plan_name                            0
# standard_charge|negotiated_dollar    0
# additional_generic_notes             0
# dtype: int64

# %%
df2 = df2.drop(cols_to_rmv, axis=1)

# %%
df2 = df2.drop('additional_generic_notes', axis=1)
df2 = df2.drop('billing_class', axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196162 entries, 0 to 196161
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   hospital_name                      196162 non-null  object
#  1   description                        196162 non-null  object
#  2   code|1                             196162 non-null  int64
#  3   code|1|type                        196162 non-null  object
#  4   code|2                             196162 non-null  int64
#  5   code|2|type                        196162 non-null  object
#  6   code|3                             196162 non-null  int64
#  7   code|3|type                        196162 non-null  object
#  8   setting                            196162 non-null  object
#  9   payer_name                         196162 non-null  object
#  10  plan_name                          196162 non-null  object
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390839 entries, 0 to 390838
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   hospital_name                      390839 non-null  object
#  1   description                        390839 non-null  object
#  2   code|1                             390839 non-null  object
#  3   code|1|type                        390839 non-null  object
#  4   code|2                             390839 non-null  float64
#  5   code|2|type                        390839 non-null  object
#  6   code|3                             390839 non-null  object
#  7   code|3|type                        390839 non-null  object
#  8   code|4                             390839 non-null  float64
#  9   code|4|type                        390839 non-null  float64
#  10  setting                            390839 non-null  object
# ...

# %%
df3 = pd.read_excel('/content/591006663_Boca-Raton-Regional-Hospital-Inc_standardcharges.xlsx')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477248 entries, 0 to 477247
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   hospital_name                          477248 non-null  object
#  1   description                            477248 non-null  object
#  2   code|1                                 445482 non-null  object
#  3   code|1|type                            445482 non-null  object
#  4   code|2                                 467334 non-null  float64
#  5   code|2|type                            467334 non-null  object
#  6   code|3                                 417079 non-null  object
#  7   code|3|type                            417079 non-null  object
#  8   code|4                                 0 non-null       float64
#  9   code|4|type                            0 non-null       float64
# ...

# %%
df3['code|3|type'].value_counts()
# Out:
# code|3|type
# HCPCS       208962
# CPT         198203
# MS-DRG        9288
# TRIS-DRG       566
# APR-DRG         60
# Name: count, dtype: int64

# %%
df3 = df3[df3['code|3|type'] == 'CPT']
df3 = df3.reset_index(drop=True)

# %%
df3 = df3.fillna(0)
df3.isnull().sum()
# Out:
# hospital_name                            0
# description                              0
# code|1                                   0
# code|1|type                              0
# code|2                                   0
# code|2|type                              0
# code|3                                   0
# code|3|type                              0
# code|4                                   0
# code|4|type                              0
# modifiers                                0
# setting                                  0
# drug_unit_of_measurement                 0
# drug_type_of_measurement                 0
# standard_charge|gross                    0
# standard_charge|discounted_cash          0
# payer_name                               0
# plan_name                                0
# standard_charge|negotiated_dollar        0
# standard_charge|negotiated_percentage    0
# standard_charge|negotiated_algorithm     0
# estimated_amount                         0
# ...

# %%
df3 = df3.drop(cols_to_rmv, axis=1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198203 entries, 0 to 198202
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   hospital_name                      198203 non-null  object
#  1   description                        198203 non-null  object
#  2   code|1                             198203 non-null  object
#  3   code|1|type                        198203 non-null  object
#  4   code|2                             198203 non-null  float64
#  5   code|2|type                        198203 non-null  object
#  6   code|3                             198203 non-null  object
#  7   code|3|type                        198203 non-null  object
#  8   code|4                             198203 non-null  float64
#  9   code|4|type                        198203 non-null  float64
#  10  setting                            198203 non-null  object
# ...

# %%
df3.to_csv('sample_file.csv', index=False)  # index=False to avoid saving row indices

# %%
df4 = pd.read_excel('/content/596012065_broward-health-coral-springs_standardcharges.xlsx')

# %%
df4.head()
# Out:
#                   hospital_name                     description code|1  \
# 0  Broward Health Coral Springs    LATE BNE L63MM 3X4 H R T SHP  C1776
# 1  Broward Health Coral Springs            PLATE 8H  MIDSHFT RT  C1713
# 2  Broward Health Coral Springs        PLATE LCP 10H 2.7MM 94MM  C1713
# 3  Broward Health Coral Springs  TRIPTORELIN 3.75MG INJ (11.25)  J3315
# 4  Broward Health Coral Springs          ROD EXT FIX SM 4X160MM    278
#
#   code|1|type    code|2 code|2|type    code|3 code|3|type  code|4 code|4|type  \
# 0       HCPCS       278          RC  49467991         CDM     NaN         NaN
# 1       HCPCS       278          RC  49115989         CDM     NaN         NaN
# 2       HCPCS       278          RC  49168110         CDM     NaN         NaN
# 3       HCPCS       636          RC  43201701         CDM     NaN         NaN
# 4          RC  49258003         CDM       NaN         NaN     NaN         NaN
#
#    ...           plan_name standard_charge|negotiated_dollar  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   hospital_name                          1048575 non-null  object
#  1   description                            1048573 non-null  object
#  2   code|1                                 1048573 non-null  object
#  3   code|1|type                            1048573 non-null  object
#  4   code|2                                 983319 non-null   object
#  5   code|2|type                            983319 non-null   object
#  6   code|3                                 688427 non-null   object
#  7   code|3|type                            688427 non-null   object
#  8   code|4                                 30180 non-null    float64
#  9   code|4|type                            30180 non-null    object
# ...

# %%
df4 = df4[df4['code|1|type'] == 'CPT']

# %%
df4 = df4.fillna(0)
df4 = df4.reset_index(drop=True)

# %%
df4 = df4.drop(cols_to_rmv, axis=1)
df4 = df4.drop(['additional_generic_notes', 'additional_payer_notes', 'billing_class'], axis=1)
df4 = df4.drop('billing_class', axis=1)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88734 entries, 0 to 88733
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   hospital_name                      88734 non-null  object
#  1   description                        88734 non-null  object
#  2   code|1                             88734 non-null  object
#  3   code|1|type                        88734 non-null  object
#  4   code|2                             88734 non-null  int64
#  5   code|2|type                        88734 non-null  object
#  6   code|3                             88734 non-null  object
#  7   code|3|type                        88734 non-null  object
#  8   code|4                             88734 non-null  float64
#  9   code|4|type                        88734 non-null  object
#  10  setting                            88734 non-null  object
# ...

# %%
df5 = pd.read_excel('/content/650844880_cleveland-clinic-florida_standardcharges.xlsx')

# %%
df5.isnull().sum()
# Out:
# hospital_name                                  0
# description                                    0
# code|1                                         0
# code|1|type                                    0
# code|2                                    222637
# code|2|type                               222637
# code|3                                    304246
# code|3|type                               304246
# billing_class                                  0
# setting                                        0
# drug_unit_of_measurement                 1048573
# drug_type_of_measurement                 1048573
# standard_charge|gross                     222637
# standard_charge|discounted_cash           222637
# payer_name                                     0
# plan_name                                      0
# modifiers                                1048474
# standard_charge|negotiated_dollar         292565
# standard_charge|negotiated_algorithm      896053
# ...

# %%
df5
# Out:
#            hospital_name                                        description  \
# 835260  Cleveland Clinic  All OP Allogeneic and Autologus Transplant-Ste...
# 835261  Cleveland Clinic                                        Cornea - IP
# 835262  Cleveland Clinic                                        Cornea - OP
# 835263  Cleveland Clinic                               Intestine Only-Adult
# 835264  Cleveland Clinic                           Intestine Only-Pediatric
# 835265  Cleveland Clinic                Kidney/Pancreas - Adult & Pediatric
#
#                code|1 code|1|type  code|2 code|2|type code|3 code|3|type  \
# 835260  ALLOPALLOAUTO         CPT     NaN         NaN    NaN         NaN
# 835261      AUTOTANIP         CPT     NaN         NaN    NaN         NaN
# 835262      AUTOTANOP         CPT     NaN         NaN    NaN         NaN
# 835263    INTESTONLYA         CPT     NaN         NaN    NaN         NaN
# ...

# %%
df5 = df5[df5['code|1|type'] == 'CPT']

# %%
df5 = df5.drop(cols_to_rmv, axis=1)
df5 = df5.drop(['billing_class'], axis=1)
df5 = df5.drop('count_of_compared_rates', axis=1)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 835260 to 835265
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   hospital_name                      6 non-null      object
#  1   description                        6 non-null      object
#  2   code|1                             6 non-null      object
#  3   code|1|type                        6 non-null      object
#  4   code|2                             0 non-null      float64
#  5   code|2|type                        0 non-null      object
#  6   code|3                             0 non-null      object
#  7   code|3|type                        0 non-null      object
#  8   setting                            6 non-null      object
#  9   payer_name                         6 non-null      object
#  10  plan_name                          6 non-null      object
# ...

# %%
df_all = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 873944 entries, 0 to 873943
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   hospital_name                      873944 non-null  object
#  1   description                        873944 non-null  object
#  2   code|1                             873944 non-null  object
#  3   code|1|type                        873944 non-null  object
#  4   code|2                             873938 non-null  float64
#  5   code|2|type                        873938 non-null  object
#  6   code|3                             873938 non-null  object
#  7   code|3|type                        873938 non-null  object
#  8   code|4                             677776 non-null  float64
#  9   code|4|type                        677776 non-null  object
#  10  setting                            873944 non-null  object
# ...

# %%
df_all.head()
# Out:
#      hospital_name               description  code|1 code|1|type  code|2  \
# 0  Bapist hospital  OneBlood CBC w auto diff  178655         CDM   305.0
# 1  Bapist hospital  OneBlood CBC w auto diff  178655         CDM   305.0
# 2  Bapist hospital  OneBlood CBC w auto diff  178655         CDM   305.0
# 3  Bapist hospital  OneBlood CBC w auto diff  178655         CDM   305.0
# 4  Bapist hospital  OneBlood CBC w auto diff  178655         CDM   305.0
#
#   code|2|type code|3 code|3|type  code|4 code|4|type setting  \
# 0          RC  85025         CPT     0.0         0.0    both
# 1          RC  85025         CPT     0.0         0.0    both
# 2          RC  85025         CPT     0.0         0.0    both
# 3          RC  85025         CPT     0.0         0.0    both
# 4          RC  85025         CPT     0.0         0.0    both
#
#               payer_name    plan_name  standard_charge|negotiated_dollar
# 0  DIMENSION HEALTH PLAN  DIMENSION 2                               22.5
# ...

# %%
df_all['hospital_name'].value_counts()
# Out:
# hospital_name
# Bapist hospital                 390839
# Boca Raton                      198203
# University of Miami             196162
# Broward Health Coral Springs     88734
# Cleveland Clinic                     6
# Name: count, dtype: int64

# %%
df_all['setting'] = df_all['setting'].replace({'Outpatient': 'outpatient', 'Inpatient': 'inpatient'})

# %%
df_all['setting'].value_counts()
# Out:
# setting
# both          521347
# outpatient    301152
# inpatient      51445
# Name: count, dtype: int64

# %%
data = df_all.to_csv('data.csv', index=False)

# %%
df_all = df_all.fillna(0)

# %%
data = df_all.to_csv('Miami-FL-data.csv', index=0)

# %%
df = df_all.drop_duplicates()

# %%
data = df.to_csv('Miami-FL-wo-duplicate.csv', index=0)
